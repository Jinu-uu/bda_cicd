# %%
import gspread
import os
import requests, json
import pandas as pd

from dotenv import load_dotenv

databaseId = "d84cffb8266b4c5bb7bbc0252c6c817d"
#https://www.notion.so/d84cffb8266b4c5bb7bbc0252c6c817d?v=aaa95ddc78834e19aa8c241a30f83a57

# 토큰값
token = os.environ.get('NOTION_API')
# 헤더
headers = {
	"Authorization":"Bearer "+ token,
    "Notion-Version":"2022-06-28"    
}

databaseId = "d84cffb8266b4c5bb7bbc0252c6c817d"
read_url = f"https://api.notion.com/v1/databases/{databaseId}/query"

# %%
params = {}
pages_and_databases = []
while True:
    search_response = requests.post(read_url, json=params, headers=headers)
    if search_response.ok is False: break
    search_response_obj = search_response.json()	
    pages_and_databases.extend(search_response_obj.get("results"))
    params["start_cursor"] = search_response_obj.get("next_cursor")


print(pages_and_databases)
# Out:
# [{'object': 'page', 'id': '53db6173-f1f2-4049-9400-ce47c3e248dd', 'created_time': '2024-05-10T02:10:00.000Z', 'last_edited_time': '2024-05-10T02:10:00.000Z', 'created_by': {'object': 'user', 'id': '1d108aa7-c8a3-47ab-9416-524ad4a8a0c2'}, 'last_edited_by': {'object': 'user', 'id': '1d108aa7-c8a3-47ab-9416-524ad4a8a0c2'}, 'cover': None, 'icon': None, 'parent': {'type': 'database_id', 'database_id': 'd84cffb8-266b-4c5b-b7bb-c0252c6c817d'}, 'archived': False, 'in_trash': False, 'properties': {'0508_과제(7주차)': {'id': '%3CHSC', 'type': 'files', 'files': []}, '최종 편집 일시': {'id': 'GDlJ', 'type': 'last_edited_time', 'last_edited_time': '2024-05-10T02:10:00.000Z'}, '0320_과제 (4주차)': {'id': 'H%3APM', 'type': 'files', 'files': []}, '0306_과제 (2주차)': {'id': 'iavU', 'type': 'files', 'files': []}, '0501_과제 (6주차)': {'id': 'mItl', 'type': 'files', 'files': []}, '0327_과제 (5주차)': {'id': 'wIbt', 'type': 'files', 'files': []}, '0313_과제(3주차)': {'id': '%7BujU', 'type': 'files', 'files': [{'name': '필수_이준교35_0313.ipynb', 'type': 'file', 'file': {'url': 'https://prod-files-secure.s3.us-west-2.amazonaws.com/301683aa-1c47-44e2-9329-ad9997783ef7/ff0b1eff-b5ce-4a82-91cc-0d4afc767ca9/%ED%95%84%EC%88%98_%EC%9D%B4%EC%A4%80%EA%B5%9035_0313.ipynb?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Content-Sha256=UNSIGNED-PAYLOAD&X-Amz-Credential=AKIAT73L2G45HZZMZUHI%2F20240513%2Fus-west-2%2Fs3%2Faws4_request&X-Amz-Date=20240513T050350Z&X-Amz-Expires=3600&X-Amz-Signature=614abef6df22e138151d0aaeebc1fcf9fc58a25a13d816ad6369bb70f555cbdf&X-Amz-SignedHeaders=host&x-id=GetObject', 'expiry_time': '2024-05-13T06:03:50.930Z'}}]}, '태그': {'id': '%7C%5DZr', 'type': 'multi_select', 'multi_select': [{'id': '510cb6cf-40e7-46e3-b8b4-098a555e47a7', 'name': 'ㅁ~ㅇ', 'color': 'pink'}]}, '이름': {'id': 'title', 'type': 'title', 'title': [{'type': 'text', 'text': {'content': '이준교35', 'link': None}, 'annotations': {'bold': False, 'italic': False, 'strikethrough': False, 'underline': False, 'code': False, 'color': 'default'}, 'plain_text': '이준교35', 'href': None}]}}, 'url': 'https://www.notion.so/35-53db6173f1f240499400ce47c3e248dd', 'public_url': None}, {'object': 'page', 'id': 'b6e73af6-eca7-4685-92b4-288408d762af', 'created_time': '2024-05-10T02:10:00.000Z', 'last_edited_time': '2024-05-10T02:10:00.000Z', 'created_by': {'object': 'user', 'id': '1d108aa7-c8a3-47ab-9416-524ad4a8a0c2'}, 'last_edited_by': {'object': 'user', 'id': '1d108aa7-c8a3-47ab-9416-524ad4a8a0c2'}, 'cover': None, 'icon': None, 'parent': {'type': 'database_id', 'database_id': 'd84cffb8-266b-4c5b-b7bb-c0252c6c817d'}, 'archived': False, 'in_trash': False, 'properties': {'0508_과제(7주차)': {'id': '%3CHSC', 'type': 'files', 'files': []}, '최종 편집 일시': {'id': 'GDlJ', 'type': 'last_edited_time', 'last_edited_time': '2024-05-10T02:10:00.000Z'}, '0320_과제 (4주차)': {'id': 'H%3APM', 'type': 'files', 'files': [{'name': '복습_박재민48_240320.ipynb', 'type': 'file', 'file': {'url': 'https://prod-files-secure.s3.us-west-2.amazonaws.com/301683aa-1c47-44e2-9329-ad9997783ef7/b07b94b0-7463-4845-a6db-41b49221cdf4/%EB%B3%B5%EC%8A%B5_%EB%B0%95%EC%9E%AC%EB%AF%BC48_240320.ipynb?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Content-Sha256=UNSIGNED-PAYLOAD&X-Amz-Credential=AKIAT73L2G45HZZMZUHI%2F20240513%2Fus-west-2%2Fs3%2Faws4_request&X-Amz-Date=20240513T050350Z&X-Amz-Expires=3600&X-Amz-Signature=1a49d0ba022712642c7488af1baccc2105471095bbdb0b82a891dfa535990b72&X-Amz-SignedHeaders=host&x-id=GetObject', 'expiry_time': '2024-05-13T06:03:50.930Z'}}, {'name': '필수_박재민48_240320.ipynb', 'type': 'file', 'file': {'url': 'https://prod-files-secure.s3.us-west-2.amazonaws.com/301683aa-1c47-44e2-9329-ad9997783ef7/a88ef229-1e7e-437e-8e63-073f7942cb51/%ED%95%84%EC%88%98_%EB%B0%95%EC%9E%AC%EB%AF%BC48_240320.ipynb?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Content-Sha256=UNSIGNED-PAYLOAD&X-Amz-Credential=AKIAT73L2G45HZZMZUHI%2F20240513%2Fus-west-2%2Fs3%2Faws4_request&X-Amz-Date=20240513T050351Z&X-Amz-Expires=3600&X-Amz-Signature=524797333191e63599d0a0a94050f6a5cb9d324af38622824678acdb8d94f4d8&X-Amz- ...

# %%
from typing import List

def get_notion_database(database_id : str)->List[dict]:
    '''
    input : notion database id
    return notion database data
    '''
    read_url = f"https://api.notion.com/v1/databases/{databaseId}/query"
    params = {}
    pages_and_databases = []
    while True:
        search_response = requests.post(read_url, json=params, headers=headers)
        if search_response.ok is False: break
        search_response_obj = search_response.json()	
        pages_and_databases.extend(search_response_obj.get("results"))
        params["start_cursor"] = search_response_obj.get("next_cursor")

    return pages_and_databases

# %%
pages_and_databases[0]
# Out:
# {'object': 'page',
#  'id': '53db6173-f1f2-4049-9400-ce47c3e248dd',
#  'created_time': '2024-05-10T02:10:00.000Z',
#  'last_edited_time': '2024-05-10T02:10:00.000Z',
#  'created_by': {'object': 'user',
#   'id': '1d108aa7-c8a3-47ab-9416-524ad4a8a0c2'},
#  'last_edited_by': {'object': 'user',
#   'id': '1d108aa7-c8a3-47ab-9416-524ad4a8a0c2'},
#  'cover': None,
#  'icon': None,
#  'parent': {'type': 'database_id',
#   'database_id': 'd84cffb8-266b-4c5b-b7bb-c0252c6c817d'},
#  'archived': False,
#  'in_trash': False,
#  'properties': {'0508_과제(7주차)': {'id': '%3CHSC', 'type': 'files', 'files': []},
#   '최종 편집 일시': {'id': 'GDlJ',
#    'type': 'last_edited_time',
#    'last_edited_time': '2024-05-10T02:10:00.000Z'},
#   '0320_과제 (4주차)': {'id': 'H%3APM', 'type': 'files', 'files': []},
#   '0306_과제 (2주차)': {'id': 'iavU', 'type': 'files', 'files': []},
#   '0501_과제 (6주차)': {'id': 'mItl', 'type': 'files', 'files': []},
#   '0327_과제 (5주차)': {'id': 'wIbt', 'type': 'files', 'files': []},
#   '0313_과제(3주차)': {'id': '%7BujU',
#    'type': 'files',
#    'files': [{'name': '필수_이준교35_0313.ipynb',
#      'type': 'file',
#      'file': {'url': 'https://prod-files-secure.s3.us-west-2.amazonaws.com/301683aa-1c47-44e2-9329-ad9997783ef7/ff0b1eff-b5ce-4a82-91cc-0d4afc767ca9/%ED%95%84%EC%88%98_%EC%9D%B4%EC%A4%80%EA%B5%9035_0313.ipynb?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Content-Sha256=UNSIGNED-PAYLOAD&X-Amz-Credential=AKIAT73L2G45HZZMZUHI%2F20240513%2Fus-west-2%2Fs3%2Faws4_request&X-Amz-Date=20240513T050350Z&X-Amz-Expires=3600&X-Amz-Signature=614abef6df22e138151d0aaeebc1fcf9fc58a25a13d816ad6369bb70f555cbdf&X-Amz-SignedHeaders=host&x-id=GetObject',
#       'expiry_time': '2024-05-13T06:03:50.930Z'}}]},
#   '태그': {'id': '%7C%5DZr',
#    'type': 'multi_select',
#    'multi_select': [{'id': '510cb6cf-40e7-46e3-b8b4-098a555e47a7',
#      'name': 'ㅁ~ㅇ',
#      'color': 'pink'}]},
#   '이름': {'id': 'title',
#    'type': 'title',
#    'title': [{'type': 'text',
#      'text': {'content': '이준교35', 'link': None},
#      'annotations': {'bold': False,
#       'italic': False,
#       'strikethrough': False,
#       'underline': False,
#       'code': False,
#       'color': 'default'},
#      'plain_text': '이준교35',
#      'href': None}]}},
#  'url': 'https://www.notion.so/35-53db6173f1f240499400ce47c3e248dd',
#  'public_url': None}

# %%
name_hw = []
for info in pages_and_databases:
    name = ''
    hw = ''
    if info['properties']['이름']['title']:
        name = info['properties']['이름']['title'][0]['plain_text']
    if info['properties']['0320_과제 (4주차)']['files']:
        hw = ' '.join([x['name'] for x in info['properties']['0320_과제 (4주차)']['files']])
    name_hw.append([name, hw])
print(name_hw)
# Out:
# [['이준교35', ''], ['박재민48', '복습_박재민48_240320.ipynb 필수_박재민48_240320.ipynb'], ['', ''], ['김수빈45', '복습_김수빈45_0320.ipynb 필수_김수빈45_0320.ipynb'], ['강예은46', '필수_강예은46_0320.ipynb 복습_강예은46_0320.ipynb'], ['김나연97', ''], ['이정욱53', '복습_이정욱53_0320.ipynb 필수_이정욱53_0320.ipynb'], ['이가현45', '필수_이가현45_0320.py 복습_이가현45_0320.py'], ['박효민32', '필수_박효민32_0320.ipynb 복습_박효민32_0320.ipynb'], ['이예지38', '복습_이예지38_20240320.ipynb 필수_이예지38_20240320.ipynb'], ['이규헌28', ''], ['정소현53', '필수_정소현53_0320.ipynb 복습_정소현53_0320.ipynb'], ['김은혜91', '복습_김은혜_0320.ipynb 필수_김은혜_0320.ipynb'], ['안경민55', '필수_안경민55_03/20.ipynb 복습_안경민55_03/20.ipynb'], ['고주희78', '복습_고주희78_240320.py 필수_고주희78_240320.py'], ['정명근44', '필수_정명근44_0320.ipynb 복습_정명근44_0320.ipynb'], ['김선교37', '복습_김선교37_0320.ipynb 필수_김선교37_0320.ipynb'], ['장윤성18', '복습-장윤성18-20240320.ipynb 필수-장윤성18-20240320.ipynb'], ['한소리67', '복습_한소리67_0320.ipynb 필수_한소리67_0320.ipynb'], ['이나윤52', '필수_이나윤52_0320.ipynb 복습_이나윤52_0320.ipynb'], ['구민준49', '복습_구민준49_0320.ipynb 필수_구민준49_0320.ipynb'], ['임현수74', '복습_임현수74_0320.py 필수_임현수74_0320.py'], ['', ''], ['구나윤68', '복습_구나윤68_20240320.ipynb 필수_구나윤68_240320.ipynb'], ['장인서61', '복습_장인서61_0320.ipynb 필수_장인서61_0320.ipynb'], ['', ''], ['오하연33', '복습_오하연33_0327.py'], ['전수빈74', '필수_전수빈74_24.3.20.ipynb.webloc 복습_전수빈74_24.3.20.ipynb.webloc'], ['오승우51', ''], ['김수현44', ''], ['', ''], ['조영인53', '필수_조영인53_0320.ipynb 복습_조영인53_0320.ipynb'], ['조주영17', '복습_조주영17_24.03.20.pdf 필수_조주영17_24.03.20.ipynb'], ['', ''], ['김도예17', '복습_김도예17_240320.ipynb 필수_김도예17_240320.ipynb'], ['김희진10', ''], ['이채은36', '필수_이채은36_0320.py 복습_이채은36_0320.py'], ['조성민55', ''], ['장연수09', ''], ['박진영20', ''], ['김한나71', '복습_김한나71_0321.ipynb 필수_김한나71_0321.ipynb'], ['이주영37', '복습_이주영37_240320.ipynb 필수_이주영37_240320.ipynb'], ['이원우20', '복습_이원우20_0320.ipynb 필수_이원우20_0320.ipynb'], ['이은지47', ''], ['이윤서56', '복습_이윤서56_0320.ipynb 필수_이윤서56_0320.ipynb'], ['조윤주86', '필수_조윤주86_0320.ipynb 복습_조윤주86_0320.ipynb'], ['', ''], ['이세연61', '복습_이세연61_0320.py 필수_이세연61_0320.ipynb'], ['이소희07', ''], ['정다경70', '복습_정다경70_0320.py 필수_정다경70_0320.py'], ['이승미22', ''], ['', ''], ['정해민78', '복습_정해민78_0320.ipynb 필수_정해민78_0320.ipynb'], ['김현지07', '복습_김현지07_0320.ipynb 필수_김현지07_0320.ipynb'], ['황정현60', '복습_황정현60_0320.py 필수_황정현60_0320.py'], ['', ''], ['신성현97', '복습_신성현97_0320.ipynb 필수_신성현97_0320.ipynb'], ['안유빈73', '복습_안유빈73_20240327.ipynb.ipynb 필수_안유빈73_20240327.ipynb.ipynb'], ['이승민87', '복습_이승민87_0320.ipynb 필수_이승민87_0320.ipynb'], ['김어진25', '복습_김어진25_0320.py 필수_김어진25_0320.py'], ['장은서70', '복습_장은서70_0320.ipynb 필수_장은서70_0320.ipynb'], ['조무빈72', ''], ['', ''], ['유지인25', '복습_유지인25_0320.ipynb 필수_유지인25_0320.ipynb'], ['강수빈08', ''], ['방예진68', '필수_방예진_20240320.ipynb 복습_방예진_20240320.ipynb'], ['', ''], ['박준모22', '복습_박준모22_240320.ipynb 필수_박준모22_240320.ipynb'], ['심현호70', ''], ['추서현98', '복습_추서현98_0320.py 필수_추서현98_0320.py'], ['백유진48', '복습_백유진48_0325.ipynb 필수_백유진48_0325.ipynb'], ['안시온38', '복습_안시온_0320.ipynb 필수_안시온_0320.ipynb'], ['오훈68', '복습_오훈68_0320.ipynb 필수_오훈68_0320.ipynb'], ['이지영32', '복습_이지영32_0320.ipynb 필수_이지영32_0320.ipynb'], ['정의진35', '필수_정의진35_0320.ipynb 복습_정의진35_0320.ipynb'], ['이지수07', '복습_이지수07_0320.py 필수_이지수07_0320.py'], ['강빈21', '필수과제_강빈_0320.ipynb 복습과제_강빈_0320.ipynb'], ['정지성80', '복습_정지성80_2024.03.22.ipynb 복습_정지성80_2024.03.24.ipynb'], ['임서정92', '복습_임서정_0320.ipynb 필수_임서정_0320.ipynb'], ['정용욱80', '필수_정용욱80_0320.py 복습_정용욱80_0320.py'], ['박상준90', '복습_박상준90_0320.ipynb 필수_박상준90_0320.ipynb'], ['김한별01', '복습_김한별_0320.ipynb 필수_김한별_0320.py'], ['심현지87', ''], ['김정재49', '복습_김정재49_0320.docx 필수_김정재49_0320.ipynb'], ['김예지51', ''], ['노다혜33', ''], ['', ''], ['남연진56', '필수_남연진56_240320.ipynb 복습_남연진56_240320.ipynb'], ['곽주영59', '복습_곽주영59.ipynb 필수_곽주영59.ipynb'], ['', ''], ['', ''], ['박상현68', '복습_박상현68_0320.ipynb 필수_박상현68_0320.ipynb'], ['이지윤69', ''], ['', ''], ['김민재75', '복습_김민재75_0320.ipynb 필수_김민재75_0320.ipynb'], ['김수영31', '필수_김수영31_3월20일.ipynb 복습_김수영31_3월20일.ipynb'], ['하태훈97', '복습_하태훈_97_24.03.20.ipynb 필수_하태훈_97_24.03.20.ipynb'], ['이원준09', '필수_이원준09_0320.ipynb 복습_이원준09_0320.ipy ...

# %%
pages_and_databases[0]['properties'].keys()
# Out:
# dict_keys(['0508_과제(7주차)', '최종 편집 일시', '0320_과제 (4주차)', '0306_과제 (2주차)', '0501_과제 (6주차)', '0327_과제 (5주차)', '0313_과제(3주차)', '태그', '이름'])

# %%
pages_and_databases[0]['properties']['이름']['title'][0]['plain_text']
# Out:
# '이준교35'

# %%
df = pd.DataFrame(name_hw, columns=['name','hw'])
df
# Out:
#       name                                                 hw
# 0    이준교35
# 1    박재민48        복습_박재민48_240320.ipynb 필수_박재민48_240320.ipynb
# 2
# 3    김수빈45            복습_김수빈45_0320.ipynb 필수_김수빈45_0320.ipynb
# 4    강예은46            필수_강예은46_0320.ipynb 복습_강예은46_0320.ipynb
# ..     ...                                                ...
# 277  우지욱64  복습_우지욱_0320.ipynb 필수_우지욱_0320.i...
# 278  이승준60            복습_이승준60_0320.ipynb 필수_이승준60_0320.ipynb
# 279  이채민73        복습_이채민73_240320.ipynb 필수_이채민73_240320.ipynb
# 280  이가영22            복습_이가영22_0320.ipynb 필수_이가영22_0320.ipynb
# 281  박소영84            복습_박소영84_0320.ipynb 필수_박소영84_0320.ipynb
#
# [282 rows x 2 columns]

# %%
df['필수'] = df['hw'].apply(lambda x : 'O' if '필수' in x else 'X')
df['복습'] = df['hw'].apply(lambda x : 'O' if '복습' in x else 'X')
df = df[df['name'] != ''].sort_values(by='name').reset_index()

# %%
import gspread
import os
from dotenv import load_dotenv

# json 파일이 위치한 경로를 값으로 줘야 합니다.

json_file_path = os.environ.get('GCP_JSON_PATH')

gc = gspread.service_account(json_file_path)

spreadsheet_url = os.environ.get('SHEET_URL')
doc = gc.open_by_url(spreadsheet_url)

main_worksheet = doc.worksheet("총명단")
python_attendance = doc.worksheet("Python 문법 기초반")

# %%
df['필수']
# Out:
# 0      O
# 1      X
# 2      X
# 3      O
# 4      X
#       ..
# 220    O
# 221    O
# 222    O
# 223    X
# 224    O
# Name: 필수, Length: 225, dtype: object

# %%
cell_list = python_attendance.range(f'H4:I{4+len(df)}')
cell_list
# Out:
# [<Cell R4C8 'X'>,
#  <Cell R4C9 'X'>,
#  <Cell R5C8 'O'>,
#  <Cell R5C9 'O'>,
#  <Cell R6C8 'X'>,
#  <Cell R6C9 'X'>,
#  <Cell R7C8 'O'>,
#  <Cell R7C9 'O'>,
#  <Cell R8C8 'O'>,
#  <Cell R8C9 'O'>,
#  <Cell R9C8 'X'>,
#  <Cell R9C9 'X'>,
#  <Cell R10C8 'O'>,
#  <Cell R10C9 'O'>,
#  <Cell R11C8 'O'>,
#  <Cell R11C9 'O'>,
#  <Cell R12C8 'O'>,
#  <Cell R12C9 'O'>,
#  <Cell R13C8 'X'>,
#  <Cell R13C9 'X'>,
#  <Cell R14C8 'X'>,
#  <Cell R14C9 'X'>,
#  <Cell R15C8 'O'>,
#  <Cell R15C9 'O'>,
#  <Cell R16C8 'X'>,
#  <Cell R16C9 'X'>,
#  <Cell R17C8 'O'>,
#  <Cell R17C9 'O'>,
#  <Cell R18C8 'X'>,
#  <Cell R18C9 'O'>,
#  <Cell R19C8 'O'>,
#  <Cell R19C9 'O'>,
#  <Cell R20C8 'O'>,
#  <Cell R20C9 'O'>,
#  <Cell R21C8 'O'>,
#  <Cell R21C9 'O'>,
#  <Cell R22C8 'O'>,
#  <Cell R22C9 'O'>,
#  <Cell R23C8 'O'>,
#  <Cell R23C9 'O'>,
#  <Cell R24C8 'O'>,
#  <Cell R24C9 'O'>,
#  <Cell R25C8 'O'>,
#  <Cell R25C9 'O'>,
#  <Cell R26C8 'X'>,
#  <Cell R26C9 'X'>,
#  <Cell R27C8 'O'>,
#  <Cell R27C9 'O'>,
#  <Cell R28C8 'O'>,
#  <Cell R28C9 'O'>,
#  <Cell R29C8 'X'>,
#  <Cell R29C9 'X'>,
#  <Cell R30C8 'X'>,
#  <Cell R30C9 'O'>,
#  <Cell R31C8 'X'>,
#  <Cell R31C9 'X'>,
#  <Cell R32C8 'X'>,
#  <Cell R32C9 'X'>,
#  <Cell R33C8 'X'>,
#  <Cell R33C9 'X'>,
#  <Cell R34C8 'X'>,
#  <Cell R34C9 'X'>,
#  <Cell R35C8 'O'>,
#  <Cell R35C9 'O'>,
#  <Cell R36C8 'O'>,
#  <Cell R36C9 'O'>,
#  <Cell R37C8 'X'>,
#  <Cell R37C9 'X'>,
#  <Cell R38C8 'O'>,
#  <Cell R38C9 'O'>,
#  <Cell R39C8 'X'>,
#  <Cell R39C9 'X'>,
#  <Cell R40C8 'O'>,
#  <Cell R40C9 'O'>,
#  <Cell R41C8 'X'>,
#  <Cell R41C9 'X'>,
#  <Cell R42C8 'X'>,
#  <Cell R42C9 'X'>,
#  <Cell R43C8 'X'>,
#  <Cell R43C9 'X'>,
#  <Cell R44C8 'O'>,
#  <Cell R44C9 'O'>,
#  <Cell R45C8 'O'>,
#  <Cell R45C9 'O'>,
#  <Cell R46C8 'O'>,
#  <Cell R46C9 'O'>,
#  <Cell R47C8 'X'>,
#  <Cell R47C9 'X'>,
#  <Cell R48C8 'O'>,
#  <Cell R48C9 'O'>,
#  <Cell R49C8 'O'>,
#  <Cell R49C9 'O'>,
#  <Cell R50C8 'X'>,
#  <Cell R50C9 'X'>,
#  <Cell R51C8 'O'>,
#  <Cell R51C9 'O'>,
#  <Cell R52C8 'X'>,
#  <Cell R52C9 'X'>,
#  <Cell R53C8 'X'>,
#  <Cell R53C9 'X'>,
#  <Cell R54C8 'X'>,
#  <Cell R54C9 'X'>,
#  <Cell R55C8 'X'>,
#  <Cell R55C9 'X'>,
#  <Cell R56C8 'O'>,
#  <Cell R56C9 'O'>,
#  <Cell R57C8 'O'>,
#  <Cell R57C9 'O'>,
#  <Cell R58C8 'O'>,
#  <Cell R58C9 'O'>,
#  <Cell R59C8 'X'>,
#  <Cell R59C9 'X'>,
#  <Cell R60C8 'O'>,
#  <Cell R60C9 'O'>,
#  <Cell R61C8 'O'>,
#  <Cell R61C9 'O'>,
#  <Cell R62C8 'O'>,
#  <Cell R62C9 'O'>,
#  <Cell R63C8 'O'>,
#  <Cell R63C9 'O'>,
#  <Cell R64C8 'O'>,
#  <Cell R64C9 'O'>,
#  <Cell R65C8 'X'>,
#  <Cell R65C9 'X'>,
#  <Cell R66C8 'X'>,
#  <Cell R66C9 'X'>,
#  <Cell R67C8 'O'>,
#  <Cell R67C9 'O'>,
#  <Cell R68C8 'X'>,
#  <Cell R68C9 'X'>,
#  <Cell R69C8 'O'>,
#  <Cell R69C9 'O'>,
#  <Cell R70C8 'X'>,
#  <Cell R70C9 'X'>,
#  <Cell R71C8 'O'>,
#  <Cell R71C9 'O'>,
#  <Cell R72C8 'X'>,
#  <Cell R72C9 'X'>,
#  <Cell R73C8 'O'>,
#  <Cell R73C9 'O'>,
#  <Cell R74C8 'O'>,
#  <Cell R74C9 'O'>,
#  <Cell R75C8 'O'>,
#  <Cell R75C9 'O'>,
#  <Cell R76C8 'O'>,
#  <Cell R76C9 'O'>,
#  <Cell R77C8 'O'>,
#  <Cell R77C9 'O'>,
#  <Cell R78C8 'O'>,
#  <Cell R78C9 'O'>,
#  <Cell R79C8 'O'>,
#  <Cell R79C9 'O'>,
#  <Cell R80C8 'O'>,
#  <Cell R80C9 'O'>,
#  <Cell R81C8 'X'>,
#  <Cell R81C9 'O'>,
#  <Cell R82C8 'O'>,
#  <Cell R82C9 'O'>,
#  <Cell R83C8 'O'>,
#  <Cell R83C9 'O'>,
#  <Cell R84C8 'O'>,
#  <Cell R84C9 'O'>,
#  <Cell R85C8 'O'>,
#  <Cell R85C9 'O'>,
#  <Cell R86C8 'X'>,
#  <Cell R86C9 'X'>,
#  <Cell R87C8 'O'>,
#  <Cell R87C9 'O'>,
#  <Cell R88C8 'X'>,
#  <Cell R88C9 'X'>,
#  <Cell R89C8 'X'>,
#  <Cell R89C9 'X'>,
#  <Cell R90C8 'X'>,
#  <Cell R90C9 'X'>,
#  <Cell R91C8 'O'>,
#  <Cell R91C9 'O'>,
#  <Cell R92C8 'O'>,
#  <Cell R92C9 'O'>,
#  <Cell R93C8 'X'>,
#  <Cell R93C9 'X'>,
#  <Cell R94C8 'X'>,
#  <Cell R94C9 'X'>,
#  <Cell R95C8 'O'>,
#  <Cell R95C9 'O'>,
#  <Cell R96C8 'X'>,
#  <Cell R96C9 'X'>,
#  <Cell R97C8 'X'>,
#  <Cell R97C9 'X'>,
#  <Cell R98C8 'O'>,
#  <Cell R98C9 'O'>,
#  <Cell R99C8 'O'>,
#  <Cell R99C9 'O'>,
#  <Cell R100C8 'O'>,
#  <Cell R100C9 'O'>,
#  <Cell R101C8 'O'>,
#  <Cell R101C9 'O'>,
#  <Cell R102C8 'O'>,
#  <Cell R102C9 'O'>,
#  <Cell R103C8 'X'>,
#  <Cell R103C9 'X'>,
#  <Cell R104C8 'O'>,
#  <Cell R104C9 'O'>,
#  <Cell R105C8 'X'>,
#  <Cell R105C9 'X'>,
#  <Cell R106C8 'O'>,
#  <Cell R106C9 'O'>,
#  <Cell R107C8 'X'>,
#  <Cell R107C9 'X'>,
#  <Cell R108C8 'O'>,
#  <Cell R108C9 'O'>,
#  <Cell R109C8 'X'>,
#  <Cell R109C9 'X'>,
#  <Cell R110C8 'O'>,
#  <Cell R110C9 'O'>,
#  <Cell R111C8 'X'>,
#  <Cell R111C9 'X'>,
#  <Cell R112C8 'X'>,
#  <Cell R112C9 'X'>,
#  <Cell R113C8 'X'>,
#  <Cell R113C9 'X'>,
#  <Cell R114C8 'X'>,
#  <Cell R114C9 'X'>,
#  <Cell R115C8 'O'>,
#  <Cell R115C9 'O'>,
#  <Cell R116C8 'X'>,
#  <Cell R116C9 'X'>,
#  <Cell R117C8 'O'>,
#  <Cell R117C9 'O'>,
#  <Cell R118C8 'X'>,
#  <Cell R118C9 'X'>,
#  <Cell R119C8 'X'>,
#  <Cell R119C9 'X'>,
#  <Cell R120C8 'O'>,
#  <Cell R120C9 'O'>,
#  <Cell R121C8 'O'>,
#  <Cell R121C9 'O'>,
#  <Cell R122C8 'O'>,
#  <Cell R122C9 'O'>,
#  <Cell R123C8 'X'>,
#  <Cell R123C9 'X'>,
#  <Cell R124C8 'O'>,
#  <Cell R124C9 'O'>,
#  <Cell R125C8 'O'>,
#  <Cell R125C9 'O'>,
#  <Cell R126C8 'O'>,
#  <Cell R126C9 'O'>,
#  <Cell R127C8 'X'>,
#  <Cell R127C9 'X'>,
#  <Cell R128C8 'O'>,
#  <Cell R128C9 'O'>,
#  <Cell R129C8 'X'>,
#  <Cell R129C9 'X'>,
#  <Cell R130C8 'X'>,
#  <Cell R130C9 'X'>,
#  <Cell R131C8 'O'>,
#  <Cell R131C9 'O'>,
#  <Cell R132C8 'O'>,
#  <Cell R132C9 'O'>,
#  <Cell R133C8 'X'>,
#  <Cell R133C9 'X'>,
#  <Cell R134C8 'X'>,
#  <Cell R134C9 'X'>,
#  <Cell R135C8 'X'>,
#  <Cell R135C9 'X'>,
#  <Cell R136C8 'O'>,
#  <Cell R136C9 'O'>,
#  <Cell R137C8 'X'>,
#  <Cell R137C9 'X'>,
#  <Cell R138C8 'O'>,
#  <Cell R138C9 'O'>,
#  <Cell R139C8 'O'>,
#  <Cell R139C9 'O'>,
#  <Cell R140C8 'O'>,
#  <Cell R140C9 'O'>,
#  <Cell R141C8 'O'>,
#  <Cell R141C9 'O'>,
#  <Cell R142C8 'O'>,
#  <Cell R142C9 'O'>,
#  <Cell R143C8 'O'>,
#  <Cell R143C9 'O'>,
#  <Cell R144C8 'X'>,
#  <Cell R144C9 'X'>,
#  <Cell R145C8 'X'>,
#  <Cell R145C9 'X'>,
#  <Cell R146C8 'X'>,
#  <Cell R146C9 'O'>,
#  <Cell R147C8 'X'>,
#  <Cell R147C9 'X'>,
#  <Cell R148C8 'O'>,
#  <Cell R148C9 'O'>,
#  <Cell R149C8 'X'>,
#  <Cell R149C9 'X'>,
#  <Cell R150C8 'X'>,
#  <Cell R150C9 'X'>,
#  <Cell R151C8 'X'>,
#  <Cell R151C9 'X'>,
#  <Cell R152C8 'X'>,
#  <Cell R152C9 'X'>,
#  <Cell R153C8 'X'>,
#  <Cell R153C9 'X'>,
#  <Cell R154C8 'X'>,
#  <Cell R154C9 'X'>,
#  <Cell R155C8 'X'>,
#  <Cell R155C9 'X'>,
#  <Cell R156C8 'O'>,
#  <Cell R156C9 'O'>,
#  <Cell R157C8 'X'>,
#  <Cell R157C9 'X'>,
#  <Cell R158C8 'X'>,
#  <Cell R158C9 'X'>,
#  <Cell R159C8 'X'>,
#  <Cell R159C9 'X'>,
#  <Cell R160C8 'O'>,
#  <Cell R160C9 'O'>,
#  <Cell R161C8 'O'>,
#  <Cell R161C9 'O'>,
#  <Cell R162C8 'X'>,
#  <Cell R162C9 'X'>,
#  <Cell R163C8 'X'>,
#  <Cell R163C9 'X'>,
#  <Cell R164C8 'X'>,
#  <Cell R164C9 'X'>,
#  <Cell R165C8 'O'>,
#  <Cell R165C9 'O'>,
#  <Cell R166C8 'O'>,
#  <Cell R166C9 'O'>,
#  <Cell R167C8 'X'>,
#  <Cell R167C9 'X'>,
#  <Cell R168C8 'O'>,
#  <Cell R168C9 'O'>,
#  <Cell R169C8 'X'>,
#  <Cell R169C9 'X'>,
#  <Cell R170C8 'X'>,
#  <Cell R170C9 'X'>,
#  <Cell R171C8 'O'>,
#  <Cell R171C9 'O'>,
#  <Cell R172C8 'X'>,
#  <Cell R172C9 'X'>,
#  <Cell R173C8 'X'>,
#  <Cell R173C9 'X'>,
#  <Cell R174C8 'O'>,
#  <Cell R174C9 'O'>,
#  <Cell R175C8 'O'>,
#  <Cell R175C9 'O'>,
#  <Cell R176C8 'X'>,
#  <Cell R176C9 'X'>,
#  <Cell R177C8 'X'>,
#  <Cell R177C9 'X'>,
#  <Cell R178C8 'O'>,
#  <Cell R178C9 'O'>,
#  <Cell R179C8 'O'>,
#  <Cell R179C9 'O'>,
#  <Cell R180C8 'O'>,
#  <Cell R180C9 'O'>,
#  <Cell R181C8 'X'>,
#  <Cell R181C9 'X'>,
#  <Cell R182C8 'O'>,
#  <Cell R182C9 'O'>,
#  <Cell R183C8 'X'>,
#  <Cell R183C9 'X'>,
#  <Cell R184C8 'X'>,
#  <Cell R184C9 'X'>,
#  <Cell R185C8 'X'>,
#  <Cell R185C9 'X'>,
#  <Cell R186C8 'X'>,
#  <Cell R186C9 'X'>,
#  <Cell R187C8 'O'>,
#  <Cell R187C9 'O'>,
#  <Cell R188C8 'O'>,
#  <Cell R188C9 'O'>,
#  <Cell R189C8 'O'>,
#  <Cell R189C9 'O'>,
#  <Cell R190C8 'X'>,
#  <Cell R190C9 'X'>,
#  <Cell R191C8 'O'>,
#  <Cell R191C9 'O'>,
#  <Cell R192C8 'X'>,
#  <Cell R192C9 'X'>,
#  <Cell R193C8 'O'>,
#  <Cell R193C9 'O'>,
#  <Cell R194C8 'O'>,
#  <Cell R194C9 'O'>,
#  <Cell R195C8 'X'>,
#  <Cell R195C9 'X'>,
#  <Cell R196C8 'X'>,
#  <Cell R196C9 'X'>,
#  <Cell R197C8 'O'>,
#  <Cell R197C9 'O'>,
#  <Cell R198C8 'O'>,
#  <Cell R198C9 'O'>,
#  <Cell R199C8 'O'>,
#  <Cell R199C9 'O'>,
#  <Cell R200C8 'X'>,
#  <Cell R200C9 'X'>,
#  <Cell R201C8 'O'>,
#  <Cell R201C9 'O'>,
#  <Cell R202C8 'X'>,
#  <Cell R202C9 'X'>,
#  <Cell R203C8 'O'>,
#  <Cell R203C9 'O'>,
#  <Cell R204C8 'X'>,
#  <Cell R204C9 'X'>,
#  <Cell R205C8 'X'>,
#  <Cell R205C9 'X'>,
#  <Cell R206C8 'X'>,
#  <Cell R206C9 'X'>,
#  <Cell R207C8 'O'>,
#  <Cell R207C9 'O'>,
#  <Cell R208C8 'O'>,
#  <Cell R208C9 'O'>,
#  <Cell R209C8 'O'>,
#  <Cell R209C9 'O'>,
#  <Cell R210C8 'X'>,
#  <Cell R210C9 'X'>,
#  <Cell R211C8 'O'>,
#  <Cell R211C9 'O'>,
#  <Cell R212C8 'X'>,
#  <Cell R212C9 'X'>,
#  <Cell R213C8 'X'>,
#  <Cell R213C9 'X'>,
#  <Cell R214C8 'X'>,
#  <Cell R214C9 'X'>,
#  <Cell R215C8 'X'>,
#  <Cell R215C9 'X'>,
#  <Cell R216C8 'X'>,
#  <Cell R216C9 'X'>,
#  <Cell R217C8 'X'>,
#  <Cell R217C9 'X'>,
#  <Cell R218C8 'X'>,
#  <Cell R218C9 'X'>,
#  <Cell R219C8 'O'>,
#  <Cell R219C9 'O'>,
#  <Cell R220C8 'X'>,
#  <Cell R220C9 'X'>,
#  <Cell R221C8 'O'>,
#  <Cell R221C9 'O'>,
#  <Cell R222C8 'X'>,
#  <Cell R222C9 'X'>,
#  <Cell R223C8 'X'>,
#  <Cell R223C9 'X'>,
#  <Cell R224C8 'O'>,
#  <Cell R224C9 'O'>,
#  <Cell R225C8 'O'>,
#  <Cell R225C9 'O'>,
#  <Cell R226C8 'O'>,
#  <Cell R226C9 'O'>,
#  <Cell R227C8 'X'>,
#  <Cell R227C9 'X'>,
#  <Cell R228C8 'X'>,
#  <Cell R228C9 'X'>,
#  <Cell R229C8 'O'>,
#  <Cell R229C9 'O'>]

# %%
#TODO def 필수/복습 update

# %%
cell_list = python_attendance.range(f'H4:H{4+len(df)}')

for i, val in enumerate(df['필수']):  #gives us a tuple of an index and value
    cell_list[i].value = val    #use the index on cell_list and the val from cell_values

python_attendance.update_cells(cell_list)
# Out:
# {'spreadsheetId': '1pmYiv4pl_ec3sE7puBIuyuqaMy2nlCiPIvhfA_oRoP8',
#  'updatedRange': "'Python 문법 기초반'!H4:H229",
#  'updatedRows': 226,
#  'updatedColumns': 1,
#  'updatedCells': 226}

# %%
cell_list = python_attendance.range(f'I4:I{4+len(df)}')

for i, val in enumerate(df['복습']):  #gives us a tuple of an index and value
    cell_list[i].value = val    #use the index on cell_list and the val from cell_values

python_attendance.update_cells(cell_list)
# Out:
# {'spreadsheetId': '1pmYiv4pl_ec3sE7puBIuyuqaMy2nlCiPIvhfA_oRoP8',
#  'updatedRange': "'Python 문법 기초반'!I4:I229",
#  'updatedRows': 226,
#  'updatedColumns': 1,
#  'updatedCells': 226}
