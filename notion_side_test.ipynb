# %%
import gspread
import os
import requests, json
import pandas as pd

from dotenv import load_dotenv


def readDatabase(databaseId, headers):
	# DataBase 조회 함수
    
    # endPoint
    readUrl = f"https://api.notion.com/v1/databases/{databaseId}/query"
    
    # api request
    res = requests.post(readUrl, headers=headers)
    data = res.json()
    return data,res

# %%
https://www.notion.so/3a2a9742f1fa40f18c432a06401310cf?v=b0d66fa409c345428c64219ed4ef3ccf

# %%
databaseId = "d84cffb8266b4c5bb7bbc0252c6c817d"
#https://www.notion.so/d84cffb8266b4c5bb7bbc0252c6c817d?v=aaa95ddc78834e19aa8c241a30f83a57

readUrl = f"https://api.notion.com/v1/databases/{databaseId}/query"

# 토큰값
token = os.environ.get('NOTION_API')
# 헤더
headers = {
	"Authorization":"Bearer "+ token,
    "Notion-Version":"2022-06-28"
    
}
# DB조회 요청
data,res = readDatabase(databaseId, headers)
data, res
# Out:
# ({'object': 'list',
#   'results': [{'object': 'page',
#     'id': '16624d14-2641-41d0-8621-830fbb484e3d',
#     'created_time': '2024-05-12T06:51:00.000Z',
#     'last_edited_time': '2024-05-12T06:51:00.000Z',
#     'created_by': {'object': 'user',
#      'id': '1d108aa7-c8a3-47ab-9416-524ad4a8a0c2'},
#     'last_edited_by': {'object': 'user',
#      'id': '1d108aa7-c8a3-47ab-9416-524ad4a8a0c2'},
#     'cover': None,
#     'icon': None,
#     'parent': {'type': 'database_id',
#      'database_id': '3a2a9742-f1fa-40f1-8c43-2a06401310cf'},
#     'archived': False,
#     'in_trash': False,
#     'properties': {'5/8~5/12': {'id': 'F%40HE', 'type': 'files', 'files': []},
#      '3/27~3/31': {'id': 'HuU%3A',
#       'type': 'files',
#       'files': [{'name': '0327 SQL.csv',
#         'type': 'file',
# ...

# %%
def get_database(api_url : str, header : str)-> dict:
    database_data = None
    params = {}
    res = requests.post(api_url, header=header)
    if res.ok:
        res_json = res.json()
        database_data = res_json.get("results")

        while res_json.get("has_more"):
            params["start_cursor"] = res_json.get("next_cursor")

            res = requests.post(api_url, json=params, headers=header)
            if res.ok:
                res_json = res.json()
                database_data.extend(res_json.get("results"))

    if database_data is None: return None
    else: return database_data[0]

# %%
get_database()

# %%
def pharsing_database(data : dict)-> dict:
    
    return dict

# %%
search_response = requests.post(read_url, headers=headers)
if search_response.ok:
    search_response_obj = search_response.json()		
    pages_and_databases = search_response_obj.get("results")

    while search_response_obj.get("has_more"):
        params["start_cursor"] = search_response_obj.get("next_cursor")
        
        search_response = requests.post(read_url, json=params, headers=headers)
        if search_response.ok:
            search_response_obj = search_response.json()
            pages_and_databases.extend(search_response_obj.get("results"))

    print(pages_and_databases)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 search_response = requests.post(read_url, headers=headers)
#       2 if search_response.ok:
#       3     search_response_obj = search_response.json()
#
# NameError: name 'read_url' is not defined

# %%
for info in pages_and_databases:
    if info['properties']['이름']['title']:
        print(info['properties']['이름']['title'][0]['plain_text'], end =' ')
    if info['properties']['0320_과제 (4주차)']['files']:
        print([x['name'] for x in info['properties']['0320_과제 (4주차)']['files']])
    else: print()
# Out:
# 이준교35
# 박재민48 ['복습_박재민48_240320.ipynb', '필수_박재민48_240320.ipynb']
#
# 김수빈45 ['복습_김수빈45_0320.ipynb', '필수_김수빈45_0320.ipynb']
# 강예은46 ['필수_강예은46_0320.ipynb', '복습_강예은46_0320.ipynb']
# 김나연97
# 이정욱53 ['복습_이정욱53_0320.ipynb', '필수_이정욱53_0320.ipynb']
# 이가현45 ['필수_이가현45_0320.py', '복습_이가현45_0320.py']
# 박효민32 ['필수_박효민32_0320.ipynb', '복습_박효민32_0320.ipynb']
# 이예지38 ['복습_이예지38_20240320.ipynb', '필수_이예지38_20240320.ipynb']
# 이규헌28
# 정소현53 ['필수_정소현53_0320.ipynb', '복습_정소현53_0320.ipynb']
# 김은혜91 ['복습_김은혜_0320.ipynb', '필수_김은혜_0320.ipynb']
# 안경민55 ['필수_안경민55_03/20.ipynb', '복습_안경민55_03/20.ipynb']
# 고주희78 ['복습_고주희78_240320.py', '필수_고주희78_240320.py']
# 정명근44 ['필수_정명근44_0320.ipynb', '복습_정명근44_0320.ipynb']
# 김선교37 ['복습_김선교37_0320.ipynb', '필수_김선교37_0320.ipynb']
# 장윤성18 ['복습-장윤성18-20240320.ipynb', '필수-장윤성18-20240320.ipynb']
# 한소리67 ['복습_한소리67_0320.ipynb', '필수_한소리67_0320.ipynb']
# 이나윤52 ['필수_이나윤52_0320.ipynb', '복습_이나윤52_0320.ipynb']
# ...

# %%
pages_and_databases[0]['properties'].keys()
# Out:
# dict_keys(['0508_과제(7주차)', '최종 편집 일시', '0320_과제 (4주차)', '0306_과제 (2주차)', '0501_과제 (6주차)', '0327_과제 (5주차)', '0313_과제(3주차)', '태그', '이름'])

# %%
pages_and_databases[2]['properties']['이름']
# Out:
# {'id': 'title', 'type': 'title', 'title': []}

# %%
pages_and_databases[1]['properties']['이름']['title'][0]['plain_text']
# Out:
# '박재민48'

# %%
pages_and_databases[1]['properties']['0508_과제(7주차)']
# Out:
# {'id': '%3CHSC', 'type': 'files', 'files': []}

# %%
pages_and_databases[1]['properties']['0320_과제 (4주차)']
# Out:
# {'id': 'H%3APM',
#  'type': 'files',
#  'files': [{'name': '복습_박재민48_240320.ipynb',
#    'type': 'file',
#    'file': {'url': 'https://prod-files-secure.s3.us-west-2.amazonaws.com/301683aa-1c47-44e2-9329-ad9997783ef7/b07b94b0-7463-4845-a6db-41b49221cdf4/%EB%B3%B5%EC%8A%B5_%EB%B0%95%EC%9E%AC%EB%AF%BC48_240320.ipynb?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Content-Sha256=UNSIGNED-PAYLOAD&X-Amz-Credential=AKIAT73L2G45HZZMZUHI%2F20240511%2Fus-west-2%2Fs3%2Faws4_request&X-Amz-Date=20240511T144944Z&X-Amz-Expires=3600&X-Amz-Signature=ed9336b6e4e8ecfa00e11cd4b07022bf9505f9090d21b41a0a53f95af5d53185&X-Amz-SignedHeaders=host&x-id=GetObject',
#     'expiry_time': '2024-05-11T15:49:44.036Z'}},
#   {'name': '필수_박재민48_240320.ipynb',
#    'type': 'file',
# ...

# %%
[x['name'] for x in pages_and_databases[1]['properties']['0320_과제 (4주차)']['files']]
# Out:
# ['복습_박재민48_240320.ipynb', '필수_박재민48_240320.ipynb']

# %%
pages_and_databases[1]['properties']['0320_과제 (4주차)']['files']
# Out:
# [{'name': '복습_박재민48_240320.ipynb',
#   'type': 'file',
#   'file': {'url': 'https://prod-files-secure.s3.us-west-2.amazonaws.com/301683aa-1c47-44e2-9329-ad9997783ef7/b07b94b0-7463-4845-a6db-41b49221cdf4/%EB%B3%B5%EC%8A%B5_%EB%B0%95%EC%9E%AC%EB%AF%BC48_240320.ipynb?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Content-Sha256=UNSIGNED-PAYLOAD&X-Amz-Credential=AKIAT73L2G45HZZMZUHI%2F20240511%2Fus-west-2%2Fs3%2Faws4_request&X-Amz-Date=20240511T144944Z&X-Amz-Expires=3600&X-Amz-Signature=ed9336b6e4e8ecfa00e11cd4b07022bf9505f9090d21b41a0a53f95af5d53185&X-Amz-SignedHeaders=host&x-id=GetObject',
#    'expiry_time': '2024-05-11T15:49:44.036Z'}},
#  {'name': '필수_박재민48_240320.ipynb',
#   'type': 'file',
# ...

# %%
pages_and_databases[1]['properties']['0501_과제 (6주차)']
# Out:
# {'id': 'mItl',
#  'type': 'files',
#  'files': [{'name': '복습_박재민48_240501.ipynb',
#    'type': 'file',
#    'file': {'url': 'https://prod-files-secure.s3.us-west-2.amazonaws.com/301683aa-1c47-44e2-9329-ad9997783ef7/8414c5b9-6e4f-44ef-8be3-c0117e7d00da/%EB%B3%B5%EC%8A%B5_%EB%B0%95%EC%9E%AC%EB%AF%BC48_240501.ipynb?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Content-Sha256=UNSIGNED-PAYLOAD&X-Amz-Credential=AKIAT73L2G45HZZMZUHI%2F20240511%2Fus-west-2%2Fs3%2Faws4_request&X-Amz-Date=20240511T144944Z&X-Amz-Expires=3600&X-Amz-Signature=d4f73d2ecfcd50d1ecdf04f8018f85c211e3b694101c2f073e72d1e99b5a7afe&X-Amz-SignedHeaders=host&x-id=GetObject',
#     'expiry_time': '2024-05-11T15:49:44.238Z'}}]}

# %%
pages_and_databases[6]['properties']['0501_과제 (6주차)']
# Out:
# {'id': 'mItl',
#  'type': 'files',
#  'files': [{'name': '복습_이정욱53_0501.ipynb',
#    'type': 'file',
#    'file': {'url': 'https://prod-files-secure.s3.us-west-2.amazonaws.com/301683aa-1c47-44e2-9329-ad9997783ef7/8775e5e0-cb26-4af4-96fa-35b7c27043bf/%EB%B3%B5%EC%8A%B5_%EC%9D%B4%EC%A0%95%EC%9A%B153_0501.ipynb?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Content-Sha256=UNSIGNED-PAYLOAD&X-Amz-Credential=AKIAT73L2G45HZZMZUHI%2F20240511%2Fus-west-2%2Fs3%2Faws4_request&X-Amz-Date=20240511T144944Z&X-Amz-Expires=3600&X-Amz-Signature=4d14c7dddec54793e9176a3d49f2cc527214ce4c784fbd507515d10a98476433&X-Amz-SignedHeaders=host&x-id=GetObject',
#     'expiry_time': '2024-05-11T15:49:44.231Z'}}]}

# %%
len(pages_and_databases)
# Out:
# 282

# %%
type(data)
# Out:
# dict

# %%
data
# Out:
# {'object': 'list',
#  'results': [{'object': 'page',
#    'id': '53db6173-f1f2-4049-9400-ce47c3e248dd',
#    'created_time': '2024-05-10T02:10:00.000Z',
#    'last_edited_time': '2024-05-10T02:10:00.000Z',
#    'created_by': {'object': 'user',
#     'id': '1d108aa7-c8a3-47ab-9416-524ad4a8a0c2'},
#    'last_edited_by': {'object': 'user',
#     'id': '1d108aa7-c8a3-47ab-9416-524ad4a8a0c2'},
#    'cover': None,
#    'icon': None,
#    'parent': {'type': 'database_id',
#     'database_id': 'd84cffb8-266b-4c5b-b7bb-c0252c6c817d'},
#    'archived': False,
#    'in_trash': False,
#    'properties': {'0508_과제(7주차)': {'id': '%3CHSC',
#      'type': 'files',
#      'files': []},
#     '최종 편집 일시': {'id': 'GDlJ',
#      'type': 'last_edited_time',
#      'last_edited_time': '2024-05-10T02:10:00.000Z'},
#     '0320_과제 (4주차)': {'id': 'H%3APM', 'type': 'files', 'files': []},
#     '0306_과제 (2주차)': {'id': 'iavU', 'type': 'files', 'files': []},
# ...

# %%
data['next_cursor']
# Out:
# '766e7f35-0826-4e39-8cff-dc5560e9723e'

# %%
len(data['results'])
# Out:
# 100

# %%
data.keys()
# Out:
# dict_keys(['object', 'results', 'next_cursor', 'has_more', 'type', 'page_or_database', 'request_id'])

# %%
data['results'][0]['properties']
# Out:
# {'0508_과제(7주차)': {'id': '%3CHSC', 'type': 'files', 'files': []},
#  '최종 편집 일시': {'id': 'GDlJ',
#   'type': 'last_edited_time',
#   'last_edited_time': '2024-05-10T02:10:00.000Z'},
#  '0320_과제 (4주차)': {'id': 'H%3APM', 'type': 'files', 'files': []},
#  '0306_과제 (2주차)': {'id': 'iavU', 'type': 'files', 'files': []},
#  '0501_과제 (6주차)': {'id': 'mItl', 'type': 'files', 'files': []},
#  '0327_과제 (5주차)': {'id': 'wIbt', 'type': 'files', 'files': []},
#  '0313_과제(3주차)': {'id': '%7BujU',
#   'type': 'files',
#   'files': [{'name': '필수_이준교35_0313.ipynb',
#     'type': 'file',
# ...

# %%
data['results'][0]['properties']
# Out:
# {'0508_과제(7주차)': {'id': '%3CHSC', 'type': 'files', 'files': []},
#  '최종 편집 일시': {'id': 'GDlJ',
#   'type': 'last_edited_time',
#   'last_edited_time': '2024-05-10T02:10:00.000Z'},
#  '0320_과제 (4주차)': {'id': 'H%3APM', 'type': 'files', 'files': []},
#  '0306_과제 (2주차)': {'id': 'iavU', 'type': 'files', 'files': []},
#  '0501_과제 (6주차)': {'id': 'mItl', 'type': 'files', 'files': []},
#  '0327_과제 (5주차)': {'id': 'wIbt', 'type': 'files', 'files': []},
#  '0313_과제(3주차)': {'id': '%7BujU',
#   'type': 'files',
#   'files': [{'name': '필수_이준교35_0313.ipynb',
#     'type': 'file',
# ...

# %%
data['results'][0].keys()
# Out:
# dict_keys(['object', 'id', 'created_time', 'last_edited_time', 'created_by', 'last_edited_by', 'cover', 'icon', 'parent', 'archived', 'in_trash', 'properties', 'url', 'public_url'])

# %%
data['results'][0]['properties'].keys()
# Out:
# dict_keys(['0508_과제(7주차)', '최종 편집 일시', '0320_과제 (4주차)', '0306_과제 (2주차)', '0501_과제 (6주차)', '0327_과제 (5주차)', '0313_과제(3주차)', '태그', '이름'])

# %%
data['results'][1]['properties']['0508_과제(7주차)']
# Out:
# {'id': '%3CHSC', 'type': 'files', 'files': []}

# %%
data['results'][0]['properties']
# Out:
# {'0508_과제(7주차)': {'id': '%3CHSC', 'type': 'files', 'files': []},
#  '최종 편집 일시': {'id': 'GDlJ',
#   'type': 'last_edited_time',
#   'last_edited_time': '2024-05-10T02:10:00.000Z'},
#  '0320_과제 (4주차)': {'id': 'H%3APM', 'type': 'files', 'files': []},
#  '0306_과제 (2주차)': {'id': 'iavU', 'type': 'files', 'files': []},
#  '0501_과제 (6주차)': {'id': 'mItl', 'type': 'files', 'files': []},
#  '0327_과제 (5주차)': {'id': 'wIbt', 'type': 'files', 'files': []},
#  '0313_과제(3주차)': {'id': '%7BujU',
#   'type': 'files',
#   'files': [{'name': '필수_이준교35_0313.ipynb',
#     'type': 'file',
# ...

# %%
data['results'][0]['properties']['0320_과제 (4주차)']
# Out:
# {'id': 'H%3APM', 'type': 'files', 'files': []}

# %%
databaseId = "2fd143f1067648b48c7b90ec4282b3ac"
#https://www.notion.so/2fd143f1067648b48c7b90ec4282b3ac?v=ff5f8832319c4add9e5251cda61cfd7d

# 토큰값
token = "secret_QYxCndWB33k8958D0nBqwXkLJFp3V30OhErvyotbE6a"

# 헤더
headers = {
	"Authorization":"Bearer "+ token,
    "Notion-Version":"2022-06-28"
}

# DB조회 요청
data,res = readDatabase(databaseId, headers)
data, res
# Out:
# ({'object': 'error',
#   'status': 404,
#   'code': 'object_not_found',
#   'message': 'Could not find database with ID: 2fd143f1-0676-48b4-8c7b-90ec4282b3ac. Make sure the relevant pages and databases are shared with your integration.',
#   'request_id': '075e0ef4-7c14-460b-87f1-fd5da227fcd4'},
#  <Response [404]>)
