# %%
import gspread
import os
import requests, json
import pandas as pd
from dotenv import load_dotenv

import dotenv

databaseId = "d84cffb8266b4c5bb7bbc0252c6c817d"
#https://www.notion.so/d84cffb8266b4c5bb7bbc0252c6c817d?v=aaa95ddc78834e19aa8c241a30f83a57

# 토큰값
token = os.environ.get('NOTION_API')
# 헤더
headers = {
	"Authorization":"Bearer "+ token,
    "Notion-Version":"2022-06-28"    
}

databaseId = "d84cffb8266b4c5bb7bbc0252c6c817d"
read_url = f"https://api.notion.com/v1/databases/{databaseId}/query"

# %%
token
# Out:
# 'secret_QYxCndWB33k8958D0nBqwXkLJFp3V30OhErvyotbE6a'

# %%
dotenv.set_key(dotenv_file, 'BUCKET', 'changedvalue123')

# %%
params = {}
pages_and_databases = []
while True:
    search_response = requests.post(read_url, json=params, headers=headers)
    if search_response.ok is False: break
    search_response_obj = search_response.json()	
    pages_and_databases.extend(search_response_obj.get("results"))
    params["start_cursor"] = search_response_obj.get("next_cursor")


print(pages_and_databases)
# Out:
# [{'object': 'page', 'id': '53db6173-f1f2-4049-9400-ce47c3e248dd', 'created_time': '2024-05-10T02:10:00.000Z', 'last_edited_time': '2024-05-10T02:10:00.000Z', 'created_by': {'object': 'user', 'id': '1d108aa7-c8a3-47ab-9416-524ad4a8a0c2'}, 'last_edited_by': {'object': 'user', 'id': '1d108aa7-c8a3-47ab-9416-524ad4a8a0c2'}, 'cover': None, 'icon': None, 'parent': {'type': 'database_id', 'database_id': 'd84cffb8-266b-4c5b-b7bb-c0252c6c817d'}, 'archived': False, 'in_trash': False, 'properties': {'0508_과제(7주차)': {'id': '%3CHSC', 'type': 'files', 'files': []}, '최종 편집 일시': {'id': 'GDlJ', 'type': 'last_edited_time', 'last_edited_time': '2024-05-10T02:10:00.000Z'}, '0320_과제 (4주차)': {'id': 'H%3APM', 'type': 'files', 'files': []}, '0306_과제 (2주차)': {'id': 'iavU', 'type': 'files', 'files': []}, '0501_과제 (6주차)': {'id': 'mItl', 'type': 'files', 'files': []}, '0327_과제 (5주차)': {'id': 'wIbt', 'type': 'files', 'files': []}, '0313_과제(3주차)': {'id': '%7BujU', 'type': 'files', 'files': [{'name': '필수_이준교35_031
# ...

# %%
from typing import List

def get_notion_database(database_id : str)->List[dict]:
    '''
    input : notion database id
    return notion database data
    '''
    read_url = f"https://api.notion.com/v1/databases/{databaseId}/query"
    params = {}
    pages_and_databases = []
    while True:
        search_response = requests.post(read_url, json=params, headers=headers)
        if search_response.ok is False: break
        search_response_obj = search_response.json()	
        pages_and_databases.extend(search_response_obj.get("results"))
        params["start_cursor"] = search_response_obj.get("next_cursor")

    return pages_and_databases

# %%
pages_and_databases[0]
# Out:
# {'object': 'page',
#  'id': '53db6173-f1f2-4049-9400-ce47c3e248dd',
#  'created_time': '2024-05-10T02:10:00.000Z',
#  'last_edited_time': '2024-05-10T02:10:00.000Z',
#  'created_by': {'object': 'user',
#   'id': '1d108aa7-c8a3-47ab-9416-524ad4a8a0c2'},
#  'last_edited_by': {'object': 'user',
#   'id': '1d108aa7-c8a3-47ab-9416-524ad4a8a0c2'},
#  'cover': None,
#  'icon': None,
#  'parent': {'type': 'database_id',
#   'database_id': 'd84cffb8-266b-4c5b-b7bb-c0252c6c817d'},
#  'archived': False,
#  'in_trash': False,
#  'properties': {'0508_과제(7주차)': {'id': '%3CHSC', 'type': 'files', 'files': []},
#   '최종 편집 일시': {'id': 'GDlJ',
#    'type': 'last_edited_time',
#    'last_edited_time': '2024-05-10T02:10:00.000Z'},
#   '0320_과제 (4주차)': {'id': 'H%3APM', 'type': 'files', 'files': []},
#   '0306_과제 (2주차)': {'id': 'iavU', 'type': 'files', 'files': []},
#   '0501_과제 (6주차)': {'id': 'mItl', 'type': 'files', 'files': []},
#   '0327_과제 (5주차)': {'id': 'wIbt', 'type': 'files', 'files': []},
# ...

# %%
pages_and_databases
# Out:
# [{'object': 'page',
#   'id': '53db6173-f1f2-4049-9400-ce47c3e248dd',
#   'created_time': '2024-05-10T02:10:00.000Z',
#   'last_edited_time': '2024-05-10T02:10:00.000Z',
#   'created_by': {'object': 'user',
#    'id': '1d108aa7-c8a3-47ab-9416-524ad4a8a0c2'},
#   'last_edited_by': {'object': 'user',
#    'id': '1d108aa7-c8a3-47ab-9416-524ad4a8a0c2'},
#   'cover': None,
#   'icon': None,
#   'parent': {'type': 'database_id',
#    'database_id': 'd84cffb8-266b-4c5b-b7bb-c0252c6c817d'},
#   'archived': False,
#   'in_trash': False,
#   'properties': {'0508_과제(7주차)': {'id': '%3CHSC',
#     'type': 'files',
#     'files': []},
#    '최종 편집 일시': {'id': 'GDlJ',
#     'type': 'last_edited_time',
#     'last_edited_time': '2024-05-10T02:10:00.000Z'},
#    '0320_과제 (4주차)': {'id': 'H%3APM', 'type': 'files', 'files': []},
#    '0306_과제 (2주차)': {'id': 'iavU', 'type': 'files', 'files': []},
#    '0501_과제 (6주차)': {'id': 'mItl', 'type': 'files', 'files': []},
# ...

# %%
name_hw = []
for info in pages_and_databases:
    name = ''
    hw = ''
    if info['properties']['이름']['title']:
        name = info['properties']['이름']['title'][0]['plain_text']
    if info['properties']['0501_과제 (6주차)']['files']:
        hw = ' '.join([x['name'] for x in info['properties']['0501_과제 (6주차)']['files']])
    name_hw.append([name, hw])
print(name_hw)
# Out:
# [['이준교35', ''], ['박재민48', '복습_박재민48_240501.ipynb'], ['', ''], ['김수빈45', '복습_김수빈45_0501.ipynb'], ['강예은46', '복습_강예은46_0501.ipynb'], ['김나연97', ''], ['이정욱53', '복습_이정욱53_0501.ipynb'], ['이가현45', '복습_이가현45_0501.py'], ['박효민32', ''], ['이예지38', '복습_이예지38_240501.ipynb'], ['이규헌28', '복습_이규헌28_24_05_01.ipynb'], ['정소현53', '복습_정소현53_0501.ipynb'], ['김은혜91', '복습_김은혜_0501.ipynb'], ['안경민55', '복습_안경민55_05/01.ipynb'], ['고주희78', '복습_고주희78_240501.py'], ['정명근44', '복습_정명근44_0501.ipynb'], ['김선교37', '복습_김선교37_0501.ipynb'], ['장윤성18', '복습_장윤성18_20240501.ipynb'], ['한소리67', '복습_한소리67_0501.ipynb'], ['이나윤52', '복습_이나윤52_0501.ipynb'], ['구민준49', '복습_구민준49_20240501.ipynb'], ['임현수74', '복습_임현수74_0501.py'], ['', ''], ['구나윤68', '복습_구나윤68_20240501.ipynb'], ['장인서61', ''], ['', ''], ['오하연33', '복습_오하연33_240501.py'], ['전수빈74', '복습_전수빈74_2024.5.3.ipynb.webloc'], ['오승우51', ''], ['김수현44', ''], ['', ''], ['조영인53', '복습_조영인53_0501.ipynb'], ['조주영17', '복습_조주영17_05.01.pdf'], ['', ''], ['김도예17', '복습_김도예17_240501.ip
# ...

# %%
pages_and_databases[0]['properties'].keys()
# Out:
# dict_keys(['0508_과제(7주차)', '최종 편집 일시', '0320_과제 (4주차)', '0306_과제 (2주차)', '0501_과제 (6주차)', '0327_과제 (5주차)', '0313_과제(3주차)', '태그', '이름'])

# %%
[x for x in list(pages_and_databases[0]['properties'].keys()) if '(6주차)' in x][0]
# Out:
# '0501_과제 (6주차)'

# %%
pages_and_databases[0]['properties']['이름']['title'][0]['plain_text']
# Out:
# '이준교35'

# %%
df = pd.DataFrame(name_hw, columns=['name','hw'])
df
# Out:
#       name                            hw
# 0    이준교35
# 1    박재민48         복습_박재민48_240501.ipynb
# 2
# 3    김수빈45           복습_김수빈45_0501.ipynb
# 4    강예은46           복습_강예은46_0501.ipynb
# ..     ...                           ...
# 277  우지욱64     복습_우지욱_0501.ipynb
# 278  이승준60  복습_이승준60_0501.ipynb
# 279  이채민73         복습_이채민73_240501.ipynb
# 280  이가영22             복습_이가영_0501.ipynb
# 281  박소영84           복습_박소영84_0501.ipynb
#
# [282 rows x 2 columns]

# %%
df['필수'] = df['hw'].apply(lambda x : 'O' if '필수' in x else 'X')
df['복습'] = df['hw'].apply(lambda x : 'O' if '복습' in x else 'X')
df = df[df['name'] != ''].sort_values(by='name').reset_index()

# %%
df
# Out:
#      index   name                               hw 필수 복습
# 0       76   강빈21                     0320 파문기.csv  X  X
# 1      235  강서윤69                                   X  X
# 2       64  강수빈08                                   X  X
# 3        4  강예은46              복습_강예은46_0501.ipynb  X  O
# 4      209  강지웅11     복습_강지웅11_0501.ipynb  X  X
# ..     ...    ...                              ... .. ..
# 220     18  한소리67              복습_한소리67_0501.ipynb  X  O
# 221    220  한혜인88           복습_한혜인88_0501.asciidoc  X  O
# 222     54  황정현60                 복습_황정현60_0501.py  X  O
# 223    216  황지희73  복습_황지희73_20240501.ipynb  X  X
# 224    199  황현하18                 복습_황현하_0502.json  X  O
#
# [225 rows x 5 columns]

# %%
import unicodedata

unicodedata.normalize('NFC', '안녕')
# Out:
# '안녕'

# %%
print(df[df['name'] == '강지웅11']['hw'])
'복습' in unicodedata.normalize('NFC',df[df['name'] == '강지웅11']['hw'][4])
# Out:
# 4    복습_강지웅11_0501.ipynb
# Name: hw, dtype: object
# True

# %%
print(df[df['name'] == '강예은46']['hw'])
'복습' in df[df['name'] == '강예은46']['hw'][3]
# Out:
# 3    복습_강예은46_0501.ipynb
# Name: hw, dtype: object
# True

# %%
import gspread
import os
from dotenv import load_dotenv

# json 파일이 위치한 경로를 값으로 줘야 합니다.

json_file_path = os.environ.get('GCP_JSON_PATH')

gc = gspread.service_account(json_file_path)

spreadsheet_url = os.environ.get('SHEET_URL')
doc = gc.open_by_url(spreadsheet_url)

main_worksheet = doc.worksheet("총명단")
python_attendance = doc.worksheet("Python 문법 기초반")

# %%
df['필수']
# Out:
# 0      O
# 1      X
# 2      X
# 3      O
# 4      X
#       ..
# 220    O
# 221    O
# 222    O
# 223    X
# 224    O
# Name: 필수, Length: 225, dtype: object

# %%
cell_list = python_attendance.range(f'H4:I{4+len(df)}')
cell_list
# Out:
# [<Cell R4C8 'X'>,
#  <Cell R4C9 'X'>,
#  <Cell R5C8 'O'>,
#  <Cell R5C9 'O'>,
#  <Cell R6C8 'X'>,
#  <Cell R6C9 'X'>,
#  <Cell R7C8 'O'>,
#  <Cell R7C9 'O'>,
#  <Cell R8C8 'O'>,
#  <Cell R8C9 'O'>,
#  <Cell R9C8 'X'>,
#  <Cell R9C9 'X'>,
#  <Cell R10C8 'O'>,
#  <Cell R10C9 'O'>,
#  <Cell R11C8 'O'>,
#  <Cell R11C9 'O'>,
#  <Cell R12C8 'O'>,
#  <Cell R12C9 'O'>,
#  <Cell R13C8 'X'>,
#  <Cell R13C9 'X'>,
#  <Cell R14C8 'X'>,
#  <Cell R14C9 'X'>,
#  <Cell R15C8 'O'>,
#  <Cell R15C9 'O'>,
#  <Cell R16C8 'X'>,
#  <Cell R16C9 'X'>,
#  <Cell R17C8 'O'>,
#  <Cell R17C9 'O'>,
#  <Cell R18C8 'X'>,
#  <Cell R18C9 'O'>,
#  <Cell R19C8 'O'>,
#  <Cell R19C9 'O'>,
#  <Cell R20C8 'O'>,
#  <Cell R20C9 'O'>,
#  <Cell R21C8 'O'>,
#  <Cell R21C9 'O'>,
#  <Cell R22C8 'O'>,
#  <Cell R22C9 'O'>,
#  <Cell R23C8 'O'>,
#  <Cell R23C9 'O'>,
#  <Cell R24C8 'O'>,
#  <Cell R24C9 'O'>,
#  <Cell R25C8 'O'>,
#  <Cell R25C9 'O'>,
#  <Cell R26C8 'X'>,
#  <Cell R26C9 'X'>,
#  <Cell R27C8 'O'>,
#  <Cell R27C9 'O'>,
# ...

# %%
#TODO def 필수/복습 update

# %%
cell_list = python_attendance.range(f'H4:H{4+len(df)}')

for i, val in enumerate(df['필수']):  #gives us a tuple of an index and value
    cell_list[i].value = val    #use the index on cell_list and the val from cell_values

python_attendance.update_cells(cell_list)
# Out:
# {'spreadsheetId': '1pmYiv4pl_ec3sE7puBIuyuqaMy2nlCiPIvhfA_oRoP8',
#  'updatedRange': "'Python 문법 기초반'!H4:H229",
#  'updatedRows': 226,
#  'updatedColumns': 1,
#  'updatedCells': 226}

# %%
cell_list = python_attendance.range(f'I4:I{4+len(df)}')

for i, val in enumerate(df['복습']):  #gives us a tuple of an index and value
    cell_list[i].value = val    #use the index on cell_list and the val from cell_values

python_attendance.update_cells(cell_list)
# Out:
# {'spreadsheetId': '1pmYiv4pl_ec3sE7puBIuyuqaMy2nlCiPIvhfA_oRoP8',
#  'updatedRange': "'Python 문법 기초반'!I4:I229",
#  'updatedRows': 226,
#  'updatedColumns': 1,
#  'updatedCells': 226}

# %%
import json
with open("data.json","r") as f:
    data = json.loads(f)

print(data)
# Out:
# {'주차': 6, '분반명': ['8기 SQL', '8기 데분입', '8기 전처리 적용', '8기 데분입', '8기 데분개념', '8기 모델링', '8기 파문기', '8기 전처리']}

# %%
data['주차']
# Out:
# 6
